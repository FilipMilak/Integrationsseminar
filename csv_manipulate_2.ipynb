# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def comma_separation(x):
    
    if type(x) == str and "," in x:
        return x.split(", ")
    
    return x

# %%
df: pd.DataFrame = pd.read_csv("umfrage_2.csv").drop("Zeitstempel", axis="columns").applymap(comma_separation)

# %%
df = df.replace(["Ausbildung", "Auszubildender"], "Azubi")
#df = df.replace({"Nein": False, "Ja": True})

# %%
def plotDensity(df: pd.DataFrame, title: str, yes_no: bool = False):
    data = df[title].explode().dropna().value_counts()
    fig, ax = plt.subplots(figsize=(8, 4))

    ax.barh(width=data, y=data.index)
    
    # annotate
    ax.bar_label(ax.containers[0], label_type='edge')

    # pad the spacing between the number and the edge of the figure
    ax.margins(y=0.1)

    ax.set_title(title)

# %%
[plotDensity(df, col) for col in df.columns]
# Out:
# C:\Users\Filip Milak\AppData\Local\Temp\ipykernel_10464\3102281807.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(8, 4))
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
for col in df.columns :
    if ".1" in col:
        print(col)
        df[col[:-2]] = df[col[:-2]].fillna(df[col])
        df = df.drop([col], axis='columns')
# Out:
# Hast Du VR/AR bereits beruflich genutzt?.1
# Welche Faktoren beeinflussen die Nutzung von VR/AR im privaten Bereich?.1
# Wie siehst Du die Zukunft von VR/AR im Bereich der privaten Unterhaltung?.1

# %%
df.columns
# Out:
# Index(['In welchem Beschäftigungsverhältnis befindest Du Dich?',
#        'Wie gut kennst Du Dich bereits mit dieser Technologie aus?',
#        'Hast Du VR/AR bereits privat benutzt?',
#        'Wie oft nutzt Du die Technologie in der Woche?',
#        'Wofür benutzt Du die VR/AR privat?  ',
#        'Wie siehst Du die Zukunft von VR/AR im Bereich der privaten Unterhaltung?',
#        'Falls Du privat an einem VR/AR Projekt entwickelt hast, beschreibe kurz worum es sich handelt. (optional)',
#        'Falls Du privat an einem VR/AR Projekt entwickelt hast, wie war die Erfahrung mit VR/AR?',
#        'Welche Faktoren beeinflussen die Nutzung von VR/AR im privaten Bereich?',
#        'Hast Du VR/AR bereits beruflich genutzt?',
#        'Wie stark wärst Du an einem beruflichen Einsatz von VR/AR interessiert?',
#        'Wie stark wärst Du an einem privaten Einsatz von VR/AR interessiert, zum Beispiel zum Spielen?',
#        'Denkst Du ein Einsatz von VR/AR kann Dich in deinem Arbeitsgebiet unterstützen?',
#        'In welchem beruflichen Bereich könnte Dich VR/AR unterstützen? (optional)',
#        'Welche Technologie hast Du bereits verwendet? (Mehrfachauswahl möglich)',
#        'In welchem Kontext wurde VR/AR eingesetzt? (Mehrfachauswahl möglich)',
#        'Wie oft nutzt Du die Technolgie in der Woche?',
#        'Wie stark hast Du Dich durch diese Technologien unterstützt gefühlt?',
#        'Wie stark hast Du Dich durch diese Technologien produktiv gefühlt?',
#        'Welche Anwendungsfälle von VR/AR sind Deiner Meinung nach am vielversprechendsten/interessantesten in Beruf/Ausbildung/Studium?',
#        'Falls Du verantwortlich für die Nutzung von VR/AR bist, welche Faktoren beeinflussen die Nutzung von VR/AR in Beruf/Ausbildung/Studium?',
#        'Inwiefern hat die Corona-Pandemie die Nutzung von VR/AR im Beruf/Ausbildung/Studium beeinflusst?',
#        'Wie zufrieden bist Du mit der aktuellen Entwicklung von VR/AR im Beruf/Ausbildung/Studium?',
#        'Bevorzugst Du einen häufigeren Einsatz von VR/AR in Beruf/Ausbildung/Studium?',
#        'Welche technischen Fortschritte wünschen Sie sich für die Zukunft von VR/AR in Beruf/Ausbildung/Studium?',
#        'Wie können Unternehmen oder Bildungseinrichtungen die Nutzung von VR/AR in Beruf/Ausbildung/Studium fördern?',
#        'Wie siehst Du die Zukunft von VR/AR in Beruf/Ausbildung/Studium?',
#        'Wie würdest Du insgesamt die Erfahrung mit AR/VR-Technologien bewerten?',
#        'Wie wahrscheinlich ist es, dass Du die VR/AR-Technologie weiterempfiehlst?',
#        '(Optional) Beschreibe kurz stichpunktartig Herausforderungen oder Probleme, die beim Einsatz aufgetreten sind.',
#        '(Optional) Beschreibe kurz stichpunktartig positive Effekte, die beim Einsatz aufgetreten sind.',
#        '(Optional) In wenigen Worten. Was für eine Anwendung ist das im beruflichen Kontext gewesen?'],
#       dtype='object')

# %%
s = df.columns[0:2].to_list()

index = df.columns.get_indexer(["Welche Technologie hast Du bereits verwendet? (Mehrfachauswahl möglich)","(Optional) In wenigen Worten. Was für eine Anwendung ist das im beruflichen Kontext gewesen?"])
b = df.columns[index[0]:(index[1]+1)].to_list()

index = df.columns.get_indexer(["Wie oft nutzt Du die Technologie in der Woche?","Welche Faktoren beeinflussen die Nutzung von VR/AR im privaten Bereich?"])
p = df.columns[index[0]:(index[1]+1)].to_list()

index = df.columns.get_indexer(["Wie stark wärst Du an einem beruflichen Einsatz von VR/AR interessiert?","In welchem beruflichen Bereich könnte Dich VR/AR unterstützen? (optional)"])
n = df.columns[index[0]:(index[1]+1)].to_list()

# %%
df_n = df[~df["Hast Du VR/AR bereits privat benutzt?"] & ~df["Hast Du VR/AR bereits beruflich genutzt?"]][s + n]
df_n.head(2)
# Out:
#   In welchem Beschäftigungsverhältnis befindest Du Dich?  \
# 1                                     Duales Studium
# 2                                     Duales Studium
#
#    Wie gut kennst Du Dich bereits mit dieser Technologie aus?  \
# 1                                                  2
# 2                                                  3
#
#    Wie stark wärst Du an einem beruflichen Einsatz von VR/AR interessiert?  \
# 1                                                3.0
# 2                                                4.0
#
#    Wie stark wärst Du an einem privaten Einsatz von VR/AR interessiert, zum Beispiel zum Spielen?  \
# 1                                                3.0
# 2                                                5.0
#
#   Denkst Du ein Einsatz von VR/AR kann Dich in deinem Arbeitsgebiet unterstützen?  \
# 1                                              False
# 2                                              False
#
#   In welchem beruflichen Bereich könnte Dich VR/AR unterstützen? (optional)
# 1                                                NaN
# 2                                                NaN

# %%
df_b = df[df["Hast Du VR/AR bereits beruflich genutzt?"]][s + b]
df_b.head(2)
# Out:
#   In welchem Beschäftigungsverhältnis befindest Du Dich?  \
# 0                                          Ausbilder
# 9                                     Duales Studium
#
#    Wie gut kennst Du Dich bereits mit dieser Technologie aus?  \
# 0                                                  4
# 9                                                  5
#
#   Welche Technologie hast Du bereits verwendet? (Mehrfachauswahl möglich)  \
# 0  [Virtual Reality, Augmented Reality, Mixed Rea...
# 9  [Virtual Reality, Augmented Reality, Mixed Rea...
#
#   In welchem Kontext wurde VR/AR eingesetzt? (Mehrfachauswahl möglich)  \
# 0               [Bildung/Lehre, Simulation/Training]
# 9  [Entwicklung/Forschung, Bildung/Lehre, Simulat...
#
#   Wie oft nutzt Du die Technolgie in der Woche?  \
# 0               Weniger als einmal in der Woche
# 9               Weniger als einmal in der Woche
#
#    Wie stark hast Du Dich durch diese Technologien unterstützt gefühlt?  \
# 0                                                4.0
# 9                                                4.0
#
#    Wie stark hast Du Dich durch diese Technologien produktiv gefühlt?  \
# 0                                                4.0
# 9                                                4.0
#
#   Welche Anwendungsfälle von VR/AR sind Deiner Meinung nach am vielversprechendsten/interessantesten in Beruf/Ausbildung/Studium?  \
# 0  [Virtuelles Training von Arbeitsprozessen, Sim...
# 9  [Virtuelles Training von Arbeitsprozessen, Sim...
#
#   Falls Du verantwortlich für die Nutzung von VR/AR bist, welche Faktoren beeinflussen die Nutzung von VR/AR in Beruf/Ausbildung/Studium?  \
# 0  [Kosten für Hardware und Software, Verfügbarke...
# 9  [Kosten für Hardware und Software, Verfügbarke...
#
#   Inwiefern hat die Corona-Pandemie die Nutzung von VR/AR im Beruf/Ausbildung/Studium beeinflusst?  \
# 0  Die Pandemie hatte keinen EInfluss auf meine N...
# 9  Die Pandemie hatte keinen EInfluss auf meine N...
#
#    Wie zufrieden bist Du mit der aktuellen Entwicklung von VR/AR im Beruf/Ausbildung/Studium?  \
# 0                                                3.0
# 9                                                2.0
#
#   Bevorzugst Du einen häufigeren Einsatz von VR/AR in Beruf/Ausbildung/Studium?  \
# 0                                              False
# 9                                               True
#
#   Welche technischen Fortschritte wünschen Sie sich für die Zukunft von VR/AR in Beruf/Ausbildung/Studium?  \
# 0  [Verbesserte Interaktion und Haptik, Größere V...
# 9  [Verbesserte Bildqualität, Verbesserte Interak...
#
#   Wie können Unternehmen oder Bildungseinrichtungen die Nutzung von VR/AR in Beruf/Ausbildung/Studium fördern?  \
# 0  Zusammenarbeit mit VR/AR-Entwicklern und -Anbi...
# 9  [Bereitstellung von Schulungen zur richtigen N...
#
#   Wie siehst Du die Zukunft von VR/AR in Beruf/Ausbildung/Studium?  \
# 0  VR/AR wird in einigen spezifischen Bereichen d...
# 9  VR/AR wird in Zukunft in allen Bereichen des B...
#
#    Wie würdest Du insgesamt die Erfahrung mit AR/VR-Technologien bewerten?  \
# 0                                                4.0
# 9                                                5.0
#
#    Wie wahrscheinlich ist es, dass Du die VR/AR-Technologie weiterempfiehlst?  \
# 0                                                4.0
# 9                                                5.0
#
#   (Optional) Beschreibe kurz stichpunktartig Herausforderungen oder Probleme, die beim Einsatz aufgetreten sind.  \
# 0  Das Kosten- und Nutzen- verhältnis stimmt noch...
# 9                                                NaN
#
#    (Optional) Beschreibe kurz stichpunktartig positive Effekte, die beim Einsatz aufgetreten sind.  \
# 0                                                NaN
# 9                                                NaN
#
#   (Optional) In wenigen Worten. Was für eine Anwendung ist das im beruflichen Kontext gewesen?
# 0                          Simulation zu HV-Technik
# 9                                                NaN

# %%
df_p = df[df["Hast Du VR/AR bereits privat benutzt?"]][s + p]

# %% [markdown]
# # Beruflicher Kontext

# %%
[plotDensity(df_b, col) for col in df_b.columns]
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Privater Kontext

# %%
[plotDensity(df_p, col) for col in df_p.columns]

# %% [markdown]
# # Alle

# %%
private = "Hast Du VR/AR bereits privat benutzt?"
job = "Hast Du VR/AR bereits beruflich genutzt?"

# %%
plotDensity(df, private, yes_no = True)

# %%
plotDensity(df, job, yes_no = True)

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.barh(y= ["beruflich & privat",
          "!beruflich & privat",
          "beruflich & !privat",
          "!beruflich & !privat",
        ],width=[
    df[df[private] & df[job]].__len__(),
    df[df[private] & ~df[job]].__len__(),
    df[~df[private] & df[job]].__len__(),
    df[~df[private] & ~df[job]].__len__()
])

# annotate
ax.bar_label(ax.containers[0], label_type='edge')

# pad the spacing between the number and the edge of the figure
ax.margins(y=0.1)

# %%
title = "Welche Technologie hast Du bereits verwendet? (Mehrfachauswahl möglich)"
plotDensity(df, title)

# %%
title = "In welchem Beschäftigungsverhältnis befindest Du Dich?"
plotDensity(df, title)

# %% [markdown]
# # Unerfahren

# %%
[plotDensity(df_n, col) for col in df_n.columns]
# Out:
# <class 'numpy.int64'>
# [None, None, None, None, None, None]
